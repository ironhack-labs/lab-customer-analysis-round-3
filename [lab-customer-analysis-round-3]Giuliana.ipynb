# %% [markdown]
# Giuliana
#
# Lab | Customer Analysis Round 3
# For this lab, we will be using the marketing_customer_analysis.csv file that you can find in the files_for_lab folder. Check out the files_for_lab/about.md to get more information if you are using the Online Excel.
#
# Note: For the next labs we will be using the same data file. Please save the code, so that you can re-use it later in the labs following this lab.
#
# Dealing with the data
# Show the dataframe shape.
# Standardize header names.
# Which columns are numerical?
# Which columns are categorical?
# Check and deal with NaN values.
# Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.
# BONUS: Put all the previously mentioned data transformations into a function.

# %%
import pandas as pd

custumers_data = pd.read_excel("/Users/giulianamiranda/Documents/Labs/lab-customer-analysis-round-2/files_for_lab/excel_files/marketing_customer_analysis.xlsx")
custumers_data
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0         Basic   College        2011-02-18         Employed      M  ...
# 1         Basic   College        2011-01-18       Unemployed      F  ...
# 2         Basic  Bachelor        2011-02-10         Employed      M  ...
# 3      Extended   College        2011-01-11         Employed      M  ...
# 4       Premium  Bachelor        2011-01-17    Medical Leave      F  ...
# ...         ...       ...               ...              ...    ...  ...
# 10905   Premium  Bachelor        2011-01-19       Unemployed      F  ...
# 10906     Basic   College        2011-01-06         Employed      F  ...
# 10907  Extended  Bachelor        2011-02-06         Employed      F  ...
# 10908   Premium   College        2011-02-13         Employed      F  ...
# 10909     Basic  Bachelor        2011-01-08       Unemployed      M  ...
#
#        Number of Open Complaints Number of Policies     Policy Type  \
# 0                            0.0                  9  Corporate Auto
# 1                            0.0                  1   Personal Auto
# 2                            0.0                  2   Personal Auto
# 3                            0.0                  2  Corporate Auto
# 4                            NaN                  7   Personal Auto
# ...                          ...                ...             ...
# 10905                        NaN                  7   Personal Auto
# 10906                        0.0                  6   Personal Auto
# 10907                        0.0                  2  Corporate Auto
# 10908                        4.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              Policy  Renew Offer Type  Sales Channel  Total Claim Amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        Vehicle Class Vehicle Size Vehicle Type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 26 columns]

# %%
# Show the dataframe shape
custumers_data.shape
# Out:
# (10910, 26)

# %%
# Standardize header names
cols = []

for i in range(len(custumers_data.columns)):
    cols.append(custumers_data.columns[i].lower().replace(' ', '_'))
    
custumers_data.columns = cols 
custumers_data
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# 0         Basic   College        2011-02-18         Employed      M  ...
# 1         Basic   College        2011-01-18       Unemployed      F  ...
# 2         Basic  Bachelor        2011-02-10         Employed      M  ...
# 3      Extended   College        2011-01-11         Employed      M  ...
# 4       Premium  Bachelor        2011-01-17    Medical Leave      F  ...
# ...         ...       ...               ...              ...    ...  ...
# 10905   Premium  Bachelor        2011-01-19       Unemployed      F  ...
# 10906     Basic   College        2011-01-06         Employed      F  ...
# 10907  Extended  Bachelor        2011-02-06         Employed      F  ...
# 10908   Premium   College        2011-02-13         Employed      F  ...
# 10909     Basic  Bachelor        2011-01-08       Unemployed      M  ...
#
#        number_of_open_complaints number_of_policies     policy_type  \
# 0                            0.0                  9  Corporate Auto
# 1                            0.0                  1   Personal Auto
# 2                            0.0                  2   Personal Auto
# 3                            0.0                  2  Corporate Auto
# 4                            NaN                  7   Personal Auto
# ...                          ...                ...             ...
# 10905                        NaN                  7   Personal Auto
# 10906                        0.0                  6   Personal Auto
# 10907                        0.0                  2  Corporate Auto
# 10908                        4.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              policy  renew_offer_type  sales_channel  total_claim_amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        vehicle_class vehicle_size vehicle_type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 26 columns]

# %%
# Which columns are numerical? Which columns are categorical?
custumers_data.dtypes
# Out:
# unnamed:_0                                int64
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                 float64
# months_since_policy_inception             int64
# number_of_open_complaints               float64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# sales_channel                            object
# total_claim_amount                      float64
# vehicle_class                            object
# vehicle_size                             object
# vehicle_type                             object
# dtype: object

# %%
# Numerical: unnamed:_0 , customer_lifetime_value , income , monthly_premium_auto, months_since_last_claim, months_since_policy_inception, number_of_open_complaints, number_of_policies ,  total_claim_amount

# %%
custumers_data.isnull().sum()
# Out:
# unnamed:_0                          0
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# vehicle_type                     5482
# dtype: int64

# %%
# Check and deal with NaN values

condition = custumers_data['vehicle_size'].isnull()
filtered_data = custumers_data[condition]
filtered_data
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 87             87  ZH92587      Oregon              8126.766397       No
# 88             88  CJ51511     Arizona             13466.920710      Yes
# 89             89  ME37450     Arizona              5210.348372       No
# 97             97  CA22248      Oregon              2505.420430       No
# 148           148  HB24005  California              2347.048112       No
# ...           ...      ...         ...                      ...      ...
# 10852       10852  KZ80424  Washington              8382.478392      Yes
# 10860       10860  GA79817     Arizona              2369.111588       No
# 10879       10879  FK95213  California             18611.453560       No
# 10883       10883  FD64348      Oregon             22563.618380       No
# 10890       10890  VQ78876      Oregon              4660.399573       No
#
#        coverage             education effective_to_date employmentstatus  \
# 87        Basic               College        2011-02-22         Disabled
# 88        Basic  High School or Below        2011-02-23         Disabled
# 89        Basic              Bachelor        2011-01-04         Employed
# 97        Basic                Master        2011-02-14         Employed
# 148       Basic               College        2011-02-02         Employed
# ...         ...                   ...               ...              ...
# 10852     Basic              Bachelor        2011-01-27         Employed
# 10860     Basic              Bachelor        2011-02-05       Unemployed
# 10879  Extended                Master        2011-01-16         Employed
# 10883     Basic  High School or Below        2011-01-17         Employed
# 10890     Basic              Bachelor        2011-02-03         Employed
#
#       gender  ...  number_of_open_complaints number_of_policies  \
# 87         F  ...                        NaN                  3
# 88         F  ...                        NaN                  2
# 89         M  ...                        0.0                  5
# 97         F  ...                        0.0                  1
# 148        M  ...                        1.0                  1
# ...      ...  ...                        ...                ...
# 10852      M  ...                        0.0                  2
# 10860      M  ...                        0.0                  1
# 10879      F  ...                        0.0                  7
# 10883      M  ...                        3.0                  2
# 10890      F  ...                        0.0                  1
#
#           policy_type        policy  renew_offer_type  sales_channel  \
# 87      Personal Auto   Personal L3            Offer1          Agent
# 88     Corporate Auto  Corporate L3            Offer2          Agent
# 89       Special Auto    Special L2            Offer1          Agent
# 97      Personal Auto   Personal L3            Offer2         Branch
# 148     Personal Auto   Personal L1            Offer1          Agent
# ...               ...           ...               ...            ...
# 10852   Personal Auto   Personal L2            Offer2    Call Center
# 10860  Corporate Auto  Corporate L2            Offer3    Call Center
# 10879   Personal Auto   Personal L3            Offer2            Web
# 10883   Personal Auto   Personal L3            Offer4         Branch
# 10890  Corporate Auto  Corporate L3            Offer1         Branch
#
#        total_claim_amount  vehicle_class vehicle_size vehicle_type
# 87             513.600000            NaN          NaN          NaN
# 88             571.200000            NaN          NaN          NaN
# 89              37.960537            NaN          NaN            A
# 97              46.278027            NaN          NaN            A
# 148            244.269407            NaN          NaN            A
# ...                   ...            ...          ...          ...
# 10852          791.878042            NaN          NaN            A
# 10860          468.000000            NaN          NaN          NaN
# 10879         1021.654003            NaN          NaN          NaN
# 10883            1.687291            NaN          NaN            A
# 10890           43.155950            NaN          NaN          NaN
#
# [622 rows x 26 columns]

# %%
# Check and deal with NaN values => I'm taking a better look at the data and the NaN values

print(custumers_data['state'].unique())
condition = custumers_data['state'].isnull()
filtered_data = custumers_data[condition]
filtered_data.head(50)
# Out:
# ['Arizona' 'California' 'Washington' 'Oregon' nan 'Nevada']
#      unnamed:_0 customer state  customer_lifetime_value response  coverage  \
# 5             5  HO81102   NaN              4745.181764      NaN     Basic
# 11           11  GE63585   NaN              2420.711888      NaN     Basic
# 58           58  BR69566   NaN             14019.833140      NaN     Basic
# 62           62  UF44021   NaN              2108.493744      NaN     Basic
# 126         126  TE60343   NaN              4716.264294      NaN     Basic
# 131         131  QK24293   NaN              6265.343299      NaN  Extended
# 155         155  JG35886   NaN              4111.888285      NaN   Premium
# 168         168  FV22585   NaN              6960.920371      NaN  Extended
# 169         169  AU23837   NaN              5010.379310      NaN     Basic
# 190         190  VZ18907   NaN             21991.615980      NaN     Basic
# 226         226  VK57280   NaN              4727.354548      NaN     Basic
# 251         251  EA52579   NaN              7687.296987      NaN     Basic
# 270         270  KX23516   NaN              4455.843406      NaN  Extended
# 304         304  PP39078   NaN              5623.611187      NaN     Basic
# 305         305  WZ83320   NaN              9061.057741      NaN   Premium
# 321         321  WQ85760   NaN              4260.335730      NaN     Basic
# 323         323  GF70857   NaN              2933.960426      NaN  Extended
# 329         329  OE15600   NaN              2544.969754      NaN     Basic
# 334         334  AV76907   NaN              4282.947971      NaN     Basic
# 347         347  WT71621   NaN              3280.457296      NaN  Extended
# 385         385  OQ61223   NaN             17497.522010      NaN     Basic
# 403         403  ET47892   NaN             12280.766610      NaN   Premium
# 404         404  XD19546   NaN              8160.689782      NaN     Basic
# 430         430  AB96670   NaN              2393.915369      NaN     Basic
# 455         455  PO56357   NaN              5363.528173      NaN     Basic
# 475         475  MB20764   NaN             17622.133200      NaN   Premium
# 478         478  DO98345   NaN             13156.748950      NaN  Extended
# 491         491  IE97795   NaN              6878.008403      NaN  Extended
# 574         574  WR85740   NaN              8149.769437      NaN     Basic
# 595         595  TN17395   NaN             22103.507200      NaN     Basic
# 597         597  EP64069   NaN              5138.244998      NaN     Basic
# 605         605  OD18225   NaN              6631.665538      NaN  Extended
# 648         648  RS29507   NaN             10395.709390      NaN  Extended
# 662         662  YS94121   NaN              5645.396665      NaN     Basic
# 670         670  RL51023   NaN              4185.757242      NaN     Basic
# 686         686  NQ71171   NaN              5107.071054      NaN     Basic
# 690         690  OO11998   NaN              4583.748377      NaN     Basic
# 720         720  ON74557   NaN             14651.615300      NaN  Extended
# 725         725  JC33752   NaN              6277.844624      NaN  Extended
# 726         726  SY86059   NaN              3731.504584      NaN  Extended
# 729         729  BV86143   NaN             21034.018150      NaN     Basic
# 732         732  QR45101   NaN              6624.611830      NaN     Basic
# 740         740  RB63074   NaN              4858.067125      NaN     Basic
# 744         744  KH24214   NaN             17857.972330      NaN     Basic
# 745         745  PB39857   NaN              5129.608404      NaN  Extended
# 764         764  ZY57929   NaN              8169.746083      NaN     Basic
# 781         781  GI55977   NaN              2337.351820      NaN     Basic
# 785         785  KN13494   NaN              5181.620895      NaN     Basic
# 794         794  RZ97514   NaN              7498.824515      NaN     Basic
# 796         796  KE61355   NaN              5272.703428      NaN     Basic
#
#                 education effective_to_date employmentstatus gender  ...  \
# 5    High School or Below        2011-02-14         Employed      M  ...
# 11               Bachelor        2011-02-07         Employed      M  ...
# 58                College        2011-02-18         Employed      M  ...
# 62               Bachelor        2011-01-02       Unemployed      M  ...
# 126  High School or Below        2011-02-25         Employed      M  ...
# 131                Doctor        2011-01-13       Unemployed      F  ...
# 155               College        2011-01-21         Employed      F  ...
# 168               College        2011-02-04         Employed      M  ...
# 169              Bachelor        2011-01-19         Employed      F  ...
# 190               College        2011-01-12         Employed      F  ...
# 226              Bachelor        2011-01-03       Unemployed      M  ...
# 251              Bachelor        2011-02-26       Unemployed      F  ...
# 270  High School or Below        2011-02-20       Unemployed      F  ...
# 304               College        2011-02-19         Employed      F  ...
# 305                Master        2011-02-18         Employed      F  ...
# 321               College        2011-02-05    Medical Leave      M  ...
# 323               College        2011-01-28       Unemployed      M  ...
# 329               College        2011-02-06         Employed      M  ...
# 334               College        2011-02-26         Employed      F  ...
# 347              Bachelor        2011-02-02         Employed      F  ...
# 385               College        2011-02-28       Unemployed      M  ...
# 403               College        2011-01-01         Employed      M  ...
# 404  High School or Below        2011-01-21       Unemployed      F  ...
# 430               College        2011-01-31       Unemployed      M  ...
# 455  High School or Below        2011-01-01         Employed      F  ...
# 475  High School or Below        2011-02-18       Unemployed      M  ...
# 478  High School or Below        2011-02-28         Employed      M  ...
# 491  High School or Below        2011-02-05         Employed      M  ...
# 574                Doctor        2011-01-26       Unemployed      F  ...
# 595               College        2011-01-30       Unemployed      M  ...
# 597              Bachelor        2011-01-08         Employed      F  ...
# 605               College        2011-01-18         Employed      M  ...
# 648              Bachelor        2011-02-10       Unemployed      F  ...
# 662  High School or Below        2011-02-27         Employed      M  ...
# 670               College        2011-02-16       Unemployed      M  ...
# 686              Bachelor        2011-02-02         Employed      M  ...
# 690                Master        2011-01-19         Employed      M  ...
# 720              Bachelor        2011-01-06         Employed      M  ...
# 725               College        2011-01-21         Employed      F  ...
# 726  High School or Below        2011-02-24       Unemployed      F  ...
# 729  High School or Below        2011-02-23         Employed      F  ...
# 732              Bachelor        2011-02-26       Unemployed      M  ...
# 740  High School or Below        2011-01-03       Unemployed      M  ...
# 744               College        2011-02-13         Employed      M  ...
# 745                Master        2011-02-23         Employed      M  ...
# 764               College        2011-01-26         Employed      F  ...
# 781  High School or Below        2011-02-23    Medical Leave      F  ...
# 785                Master        2011-02-03         Employed      F  ...
# 794                Master        2011-01-27       Unemployed      F  ...
# 796  High School or Below        2011-02-16         Employed      F  ...
#
#      number_of_open_complaints number_of_policies     policy_type  \
# 5                          0.0                  7   Personal Auto
# 11                         0.0                  1  Corporate Auto
# 58                         0.0                  2   Personal Auto
# 62                         0.0                  1   Personal Auto
# 126                        1.0                  3  Corporate Auto
# 131                        1.0                  4  Corporate Auto
# 155                        0.0                  1   Personal Auto
# 168                        0.0                  3   Personal Auto
# 169                        NaN                  7  Corporate Auto
# 190                        0.0                  2   Personal Auto
# 226                        0.0                  3   Personal Auto
# 251                        0.0                  3   Personal Auto
# 270                        0.0                  1   Personal Auto
# 304                        0.0                  3    Special Auto
# 305                        0.0                  8   Personal Auto
# 321                        0.0                  1  Corporate Auto
# 323                        0.0                  1   Personal Auto
# 329                        NaN                  1   Personal Auto
# 334                        1.0                  1   Personal Auto
# 347                        0.0                  1   Personal Auto
# 385                        0.0                  2   Personal Auto
# 403                        0.0                  2   Personal Auto
# 404                        0.0                  7   Personal Auto
# 430                        0.0                  1   Personal Auto
# 455                        1.0                  8   Personal Auto
# 475                        0.0                  3  Corporate Auto
# 478                        0.0                  2   Personal Auto
# 491                        0.0                  5  Corporate Auto
# 574                        0.0                  2  Corporate Auto
# 595                        0.0                  2   Personal Auto
# 597                        0.0                  9  Corporate Auto
# 605                        0.0                  3   Personal Auto
# 648                        0.0                  2   Personal Auto
# 662                        0.0                  9   Personal Auto
# 670                        0.0                  3  Corporate Auto
# 686                        0.0                  7   Personal Auto
# 690                        4.0                  1   Personal Auto
# 720                        0.0                  2   Personal Auto
# 725                        1.0                  9   Personal Auto
# 726                        NaN                  1  Corporate Auto
# 729                        0.0                  2   Personal Auto
# 732                        0.0                  2  Corporate Auto
# 740                        0.0                  3   Personal Auto
# 744                        1.0                  2   Personal Auto
# 745                        0.0                  1   Personal Auto
# 764                        0.0                  3   Personal Auto
# 781                        0.0                  1   Personal Auto
# 785                        NaN                  6   Personal Auto
# 794                        0.0                  2   Personal Auto
# 796                        0.0                  3  Corporate Auto
#
#            policy  renew_offer_type  sales_channel  total_claim_amount  \
# 5     Personal L3            Offer1          Agent          292.800000
# 11   Corporate L3            Offer1    Call Center          199.551735
# 58    Personal L3            Offer4    Call Center          469.882367
# 62    Personal L2            Offer1          Agent          351.856810
# 126  Corporate L3            Offer2          Agent          292.800000
# 131  Corporate L1            Offer1          Agent          481.025786
# 155   Personal L2            Offer2    Call Center          480.073548
# 168   Personal L1            Offer1    Call Center           16.711329
# 169  Corporate L3            Offer1          Agent          295.871784
# 190   Personal L3            Offer2         Branch          132.139111
# 226   Personal L2            Offer2    Call Center          345.600000
# 251   Personal L1            Offer3    Call Center          523.200000
# 270   Personal L3            Offer4          Agent          699.615192
# 304    Special L1            Offer4         Branch          340.800000
# 305   Personal L1            Offer3            Web          419.303041
# 321  Corporate L3            Offer3         Branch          856.800000
# 323   Personal L3            Offer2    Call Center          199.851201
# 329   Personal L3            Offer2    Call Center          139.745936
# 334   Personal L3            Offer1          Agent          166.937747
# 347   Personal L3            Offer2            Web          251.756739
# 385   Personal L2            Offer1          Agent          350.400000
# 403   Personal L3            Offer1         Branch          489.600000
# 404   Personal L1            Offer1            Web          523.200000
# 430   Personal L1            Offer1         Branch          425.266308
# 455   Personal L3            Offer1            Web          272.445607
# 475  Corporate L2            Offer4         Branch         1814.400000
# 478   Personal L3            Offer2            Web          371.458196
# 491  Corporate L1            Offer3          Agent          485.013840
# 574  Corporate L3            Offer2    Call Center          340.800000
# 595   Personal L3            Offer1         Branch          489.600000
# 597  Corporate L3            Offer3            Web          272.649844
# 605   Personal L2            Offer3          Agent          403.200000
# 648   Personal L3            Offer2          Agent          337.797690
# 662   Personal L1            Offer1    Call Center          428.734656
# 670  Corporate L1            Offer2    Call Center          492.644465
# 686   Personal L2            Offer1          Agent          128.900320
# 690   Personal L2            Offer1         Branch          764.592151
# 720   Personal L2            Offer3         Branch          393.151377
# 725   Personal L3            Offer2          Agent          450.129276
# 726  Corporate L3            Offer1          Agent          460.800000
# 729   Personal L2            Offer4    Call Center          219.209762
# 732  Corporate L3            Offer1         Branch          297.600000
# 740   Personal L1            Offer2         Branch          482.400000
# 744   Personal L3            Offer3          Agent          445.287788
# 745   Personal L3            Offer2          Agent          343.139611
# 764   Personal L2            Offer1          Agent          499.200000
# 781   Personal L1            Offer2    Call Center          292.800000
# 785   Personal L1            Offer2          Agent          307.200000
# 794   Personal L1            Offer3          Agent          316.800000
# 796  Corporate L1            Offer2            Web          328.366827
#
#      vehicle_class vehicle_size vehicle_type
# 5    Four-Door Car      Medsize            A
# 11    Two-Door Car      Medsize          NaN
# 58    Two-Door Car        Small          NaN
# 62    Two-Door Car      Medsize          NaN
# 126  Four-Door Car      Medsize            A
# 131  Four-Door Car      Medsize          NaN
# 155  Four-Door Car      Medsize            A
# 168  Four-Door Car      Medsize          NaN
# 169  Four-Door Car        Large            A
# 190            SUV        Large          NaN
# 226  Four-Door Car      Medsize          NaN
# 251            SUV      Medsize          NaN
# 270            SUV      Medsize          NaN
# 304  Four-Door Car        Small            A
# 305  Four-Door Car      Medsize            A
# 321            SUV      Medsize          NaN
# 323  Four-Door Car      Medsize            A
# 329   Two-Door Car      Medsize            A
# 334            SUV      Medsize            A
# 347  Four-Door Car      Medsize            A
# 385   Two-Door Car      Medsize          NaN
# 403   Two-Door Car      Medsize            A
# 404            SUV      Medsize          NaN
# 430  Four-Door Car      Medsize          NaN
# 455  Four-Door Car      Medsize            A
# 475     Luxury SUV      Medsize            A
# 478   Two-Door Car      Medsize          NaN
# 491            NaN          NaN            A
# 574   Two-Door Car      Medsize            A
# 595            SUV      Medsize            A
# 597  Four-Door Car      Medsize          NaN
# 605  Four-Door Car      Medsize            A
# 648  Four-Door Car      Medsize          NaN
# 662  Four-Door Car        Small            A
# 670  Four-Door Car        Small          NaN
# 686  Four-Door Car      Medsize          NaN
# 690            SUV      Medsize          NaN
# 720            SUV      Medsize          NaN
# 725   Two-Door Car        Large          NaN
# 726  Four-Door Car        Large            A
# 729  Four-Door Car      Medsize            A
# 732   Two-Door Car      Medsize          NaN
# 740  Four-Door Car      Medsize          NaN
# 744            NaN          NaN          NaN
# 745            SUV        Large          NaN
# 764            SUV      Medsize            A
# 781  Four-Door Car        Small          NaN
# 785  Four-Door Car        Small            A
# 794  Four-Door Car      Medsize          NaN
# 796  Four-Door Car      Medsize            A
#
# [50 rows x 26 columns]

# %%
custumers_data[custumers_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [unnamed:_0, customer, state, customer_lifetime_value, response, coverage, education, effective_to_date, employmentstatus, gender, income, location_code, marital_status, monthly_premium_auto, months_since_last_claim, months_since_policy_inception, number_of_open_complaints, number_of_policies, policy_type, policy, renew_offer_type, sales_channel, total_claim_amount, vehicle_class, vehicle_size, vehicle_type]
# Index: []
#
# [0 rows x 26 columns]

# %%
# Dealing with Nan at the column vehicle_type

print(custumers_data['vehicle_type'].unique())

# More than half of the values are NaN. Also, there´s only one other option "A". So, I believe the best option is to drop the entire column 

custumers_data.drop(['vehicle_type'], inplace=True, axis=1)

custumers_data.columns
# Out:
# [nan 'A']
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %%
# The total income is  409.520.867
custumers_data['income'].sum()
# Out:
# 409520867

# %%
# The visual analysis shows that that Nan in 4 columns are closely related. 
# It´s important to check the possible impact of the removal of rows with the NaN on the total income

hip_custumers_data = custumers_data
hip_custumers_data = hip_custumers_data.dropna()
hip_custumers_data
hip_custumers_data['income'].sum()

# The income without the NaN values is 343.962.509

# Thats a 15% difference. I´d say i'd keep the NaN for now and later deal with them, once I figure out what is the most important category of data
# Out:
# 343962509

# %%
# Datetime format - Extract the months from the dataset and store in a separate column 
 
import time 
df = custumers_data['effective_to_date'].dt.month
print(df.unique())

custumers_data['month'] = custumers_data['effective_to_date'].dt.month
custumers_data
# Out:
# [2 1]
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# 0         Basic   College        2011-02-18         Employed      M  ...
# 1         Basic   College        2011-01-18       Unemployed      F  ...
# 2         Basic  Bachelor        2011-02-10         Employed      M  ...
# 3      Extended   College        2011-01-11         Employed      M  ...
# 4       Premium  Bachelor        2011-01-17    Medical Leave      F  ...
# ...         ...       ...               ...              ...    ...  ...
# 10905   Premium  Bachelor        2011-01-19       Unemployed      F  ...
# 10906     Basic   College        2011-01-06         Employed      F  ...
# 10907  Extended  Bachelor        2011-02-06         Employed      F  ...
# 10908   Premium   College        2011-02-13         Employed      F  ...
# 10909     Basic  Bachelor        2011-01-08       Unemployed      M  ...
#
#        number_of_open_complaints number_of_policies     policy_type  \
# 0                            0.0                  9  Corporate Auto
# 1                            0.0                  1   Personal Auto
# 2                            0.0                  2   Personal Auto
# 3                            0.0                  2  Corporate Auto
# 4                            NaN                  7   Personal Auto
# ...                          ...                ...             ...
# 10905                        NaN                  7   Personal Auto
# 10906                        0.0                  6   Personal Auto
# 10907                        0.0                  2  Corporate Auto
# 10908                        4.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              policy  renew_offer_type  sales_channel  total_claim_amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        vehicle_class vehicle_size month
# 0      Four-Door Car      Medsize     2
# 1      Four-Door Car      Medsize     1
# 2                SUV      Medsize     2
# 3      Four-Door Car      Medsize     1
# 4      Four-Door Car      Medsize     1
# ...              ...          ...   ...
# 10905     Luxury Car      Medsize     1
# 10906  Four-Door Car      Medsize     1
# 10907     Luxury SUV      Medsize     2
# 10908            SUV      Medsize     2
# 10909            SUV      Medsize     1
#
# [10910 rows x 26 columns]

# %%
#Filtering to show only first quarter 

condition = (custumers_data['month'] >= 1) & (custumers_data['month'] <= 3)
custumers_data[condition]
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# 0         Basic   College        2011-02-18         Employed      M  ...
# 1         Basic   College        2011-01-18       Unemployed      F  ...
# 2         Basic  Bachelor        2011-02-10         Employed      M  ...
# 3      Extended   College        2011-01-11         Employed      M  ...
# 4       Premium  Bachelor        2011-01-17    Medical Leave      F  ...
# ...         ...       ...               ...              ...    ...  ...
# 10905   Premium  Bachelor        2011-01-19       Unemployed      F  ...
# 10906     Basic   College        2011-01-06         Employed      F  ...
# 10907  Extended  Bachelor        2011-02-06         Employed      F  ...
# 10908   Premium   College        2011-02-13         Employed      F  ...
# 10909     Basic  Bachelor        2011-01-08       Unemployed      M  ...
#
#        number_of_open_complaints number_of_policies     policy_type  \
# 0                            0.0                  9  Corporate Auto
# 1                            0.0                  1   Personal Auto
# 2                            0.0                  2   Personal Auto
# 3                            0.0                  2  Corporate Auto
# 4                            NaN                  7   Personal Auto
# ...                          ...                ...             ...
# 10905                        NaN                  7   Personal Auto
# 10906                        0.0                  6   Personal Auto
# 10907                        0.0                  2  Corporate Auto
# 10908                        4.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              policy  renew_offer_type  sales_channel  total_claim_amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        vehicle_class vehicle_size month
# 0      Four-Door Car      Medsize     2
# 1      Four-Door Car      Medsize     1
# 2                SUV      Medsize     2
# 3      Four-Door Car      Medsize     1
# 4      Four-Door Car      Medsize     1
# ...              ...          ...   ...
# 10905     Luxury Car      Medsize     1
# 10906  Four-Door Car      Medsize     1
# 10907     Luxury SUV      Medsize     2
# 10908            SUV      Medsize     2
# 10909            SUV      Medsize     1
#
# [10910 rows x 26 columns]

# %%
# BONUS: Put all the previously mentioned data transformations into a function.

# %%
def optimize(data):
    # Standardize header names
    cols = [col.lower().replace(' ', '_') for col in data.columns]
    data.columns = cols
    
    # show df shape
    print("DF shape:")
    print(data.shape)
    
    # show types
    print("DF Types")
    print(data.dtypes)
    
    # Checking for NaN values
    print("Sum of NaN values")
    print(data.isnull().sum())
    
    # Extract the months from the dataset and store in a separate column 

    data['month'] = data['effective_to_date'].dt.month
    
    condition = (data['month'] >= 1) & (data['month'] <= 3)
    print(data[condition])
    
    return data

# %%
optimize(custumers_data)
# Out:
# DF shape:
# (10910, 26)
# DF Types
# unnamed:_0                                int64
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                 float64
# months_since_policy_inception             int64
# number_of_open_complaints               float64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# sales_channel                            object
# total_claim_amount                      float64
# vehicle_class                            object
# vehicle_size                             object
# month                                     int64
# dtype: object
# Sum of NaN values
# unnamed:_0                         0
# customer                           0
# state                            631
# customer_lifetime_value            0
# response                         631
# coverage                           0
# education                          0
# effective_to_date                  0
# employmentstatus                   0
# gender                             0
# income                             0
# location_code                      0
# marital_status                     0
# monthly_premium_auto               0
# months_since_last_claim          633
# months_since_policy_inception      0
# number_of_open_complaints        633
# number_of_policies                 0
# policy_type                        0
# policy                             0
# renew_offer_type                   0
# sales_channel                      0
# total_claim_amount                 0
# vehicle_class                    622
# vehicle_size                     622
# month                              0
# dtype: int64
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# 0         Basic   College        2011-02-18         Employed      M  ...
# 1         Basic   College        2011-01-18       Unemployed      F  ...
# 2         Basic  Bachelor        2011-02-10         Employed      M  ...
# 3      Extended   College        2011-01-11         Employed      M  ...
# 4       Premium  Bachelor        2011-01-17    Medical Leave      F  ...
# ...         ...       ...               ...              ...    ...  ...
# 10905   Premium  Bachelor        2011-01-19       Unemployed      F  ...
# 10906     Basic   College        2011-01-06         Employed      F  ...
# 10907  Extended  Bachelor        2011-02-06         Employed      F  ...
# 10908   Premium   College        2011-02-13         Employed      F  ...
# 10909     Basic  Bachelor        2011-01-08       Unemployed      M  ...
#
#        number_of_open_complaints number_of_policies     policy_type  \
# 0                            0.0                  9  Corporate Auto
# 1                            0.0                  1   Personal Auto
# 2                            0.0                  2   Personal Auto
# 3                            0.0                  2  Corporate Auto
# 4                            NaN                  7   Personal Auto
# ...                          ...                ...             ...
# 10905                        NaN                  7   Personal Auto
# 10906                        0.0                  6   Personal Auto
# 10907                        0.0                  2  Corporate Auto
# 10908                        4.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              policy  renew_offer_type  sales_channel  total_claim_amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        vehicle_class vehicle_size month
# 0      Four-Door Car      Medsize     2
# 1      Four-Door Car      Medsize     1
# 2                SUV      Medsize     2
# 3      Four-Door Car      Medsize     1
# 4      Four-Door Car      Medsize     1
# ...              ...          ...   ...
# 10905     Luxury Car      Medsize     1
# 10906  Four-Door Car      Medsize     1
# 10907     Luxury SUV      Medsize     2
# 10908            SUV      Medsize     2
# 10909            SUV      Medsize     1
#
# [10910 rows x 26 columns]
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# 0         Basic   College        2011-02-18         Employed      M  ...
# 1         Basic   College        2011-01-18       Unemployed      F  ...
# 2         Basic  Bachelor        2011-02-10         Employed      M  ...
# 3      Extended   College        2011-01-11         Employed      M  ...
# 4       Premium  Bachelor        2011-01-17    Medical Leave      F  ...
# ...         ...       ...               ...              ...    ...  ...
# 10905   Premium  Bachelor        2011-01-19       Unemployed      F  ...
# 10906     Basic   College        2011-01-06         Employed      F  ...
# 10907  Extended  Bachelor        2011-02-06         Employed      F  ...
# 10908   Premium   College        2011-02-13         Employed      F  ...
# 10909     Basic  Bachelor        2011-01-08       Unemployed      M  ...
#
#        number_of_open_complaints number_of_policies     policy_type  \
# 0                            0.0                  9  Corporate Auto
# 1                            0.0                  1   Personal Auto
# 2                            0.0                  2   Personal Auto
# 3                            0.0                  2  Corporate Auto
# 4                            NaN                  7   Personal Auto
# ...                          ...                ...             ...
# 10905                        NaN                  7   Personal Auto
# 10906                        0.0                  6   Personal Auto
# 10907                        0.0                  2  Corporate Auto
# 10908                        4.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              policy  renew_offer_type  sales_channel  total_claim_amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        vehicle_class vehicle_size month
# 0      Four-Door Car      Medsize     2
# 1      Four-Door Car      Medsize     1
# 2                SUV      Medsize     2
# 3      Four-Door Car      Medsize     1
# 4      Four-Door Car      Medsize     1
# ...              ...          ...   ...
# 10905     Luxury Car      Medsize     1
# 10906  Four-Door Car      Medsize     1
# 10907     Luxury SUV      Medsize     2
# 10908            SUV      Medsize     2
# 10909            SUV      Medsize     1
#
# [10910 rows x 26 columns]

# %% [markdown]
# Lab 3

# %%
import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

df_custumers_data = pd.read_csv("/Users/giulianamiranda/Documents/Labs/lab-customer-analysis-round-2/files_for_lab/csv_files/marketing_customer_analysis.csv")
df_custumers_data
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0         Basic   College           2/18/11         Employed      M  ...
# 1         Basic   College           1/18/11       Unemployed      F  ...
# 2         Basic  Bachelor           2/10/11         Employed      M  ...
# 3      Extended   College           1/11/11         Employed      M  ...
# 4       Premium  Bachelor           1/17/11    Medical Leave      F  ...
# ...         ...       ...               ...              ...    ...  ...
# 10905   Premium  Bachelor           1/19/11       Unemployed      F  ...
# 10906     Basic   College            1/6/11         Employed      F  ...
# 10907  Extended  Bachelor            2/6/11         Employed      F  ...
# 10908   Premium   College           2/13/11         Employed      F  ...
# 10909     Basic  Bachelor            1/8/11       Unemployed      M  ...
#
#        Number of Open Complaints Number of Policies     Policy Type  \
# 0                            0.0                  9  Corporate Auto
# 1                            0.0                  1   Personal Auto
# 2                            0.0                  2   Personal Auto
# 3                            0.0                  2  Corporate Auto
# 4                            NaN                  7   Personal Auto
# ...                          ...                ...             ...
# 10905                        NaN                  7   Personal Auto
# 10906                        0.0                  6   Personal Auto
# 10907                        0.0                  2  Corporate Auto
# 10908                        4.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              Policy  Renew Offer Type  Sales Channel  Total Claim Amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        Vehicle Class Vehicle Size Vehicle Type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 26 columns]

# %%
cols2 = []

for i in range(len(df_custumers_data.columns)):
    cols2.append(df_custumers_data.columns[i].lower().replace(' ', '_'))
    
df_custumers_data.columns = cols

# %%
df_custumers_data
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# 0         Basic   College           2/18/11         Employed      M  ...
# 1         Basic   College           1/18/11       Unemployed      F  ...
# 2         Basic  Bachelor           2/10/11         Employed      M  ...
# 3      Extended   College           1/11/11         Employed      M  ...
# 4       Premium  Bachelor           1/17/11    Medical Leave      F  ...
# ...         ...       ...               ...              ...    ...  ...
# 10905   Premium  Bachelor           1/19/11       Unemployed      F  ...
# 10906     Basic   College            1/6/11         Employed      F  ...
# 10907  Extended  Bachelor            2/6/11         Employed      F  ...
# 10908   Premium   College           2/13/11         Employed      F  ...
# 10909     Basic  Bachelor            1/8/11       Unemployed      M  ...
#
#        number_of_open_complaints number_of_policies     policy_type  \
# 0                            0.0                  9  Corporate Auto
# 1                            0.0                  1   Personal Auto
# 2                            0.0                  2   Personal Auto
# 3                            0.0                  2  Corporate Auto
# 4                            NaN                  7   Personal Auto
# ...                          ...                ...             ...
# 10905                        NaN                  7   Personal Auto
# 10906                        0.0                  6   Personal Auto
# 10907                        0.0                  2  Corporate Auto
# 10908                        4.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              policy  renew_offer_type  sales_channel  total_claim_amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        vehicle_class vehicle_size vehicle_type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 26 columns]

# %%
df_custumers_data.drop(['vehicle_type'], inplace=True, axis=1)

# %%
# Show dataframe info

df_custumers_data.shape
# Out:
# (10910, 25)

# %%
df_custumers_data.dtypes
# Out:
# unnamed:_0                         int64
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# vehicle_class                     object
# vehicle_size                      object
# dtype: object

# %%
# Show a plot of the total number of responses.

df_custumers_data['response'] = df_custumers_data['response'].astype(str)
df_custumers_data['response']
# Out:
# 0         No
# 1         No
# 2         No
# 3        Yes
# 4         No
#         ...
# 10905     No
# 10906     No
# 10907     No
# 10908     No
# 10909    nan
# Name: response, Length: 10910, dtype: object

# %%
sns.histplot(df_custumers_data['response'])
plt.show()

# %%
# Show a plot of the response rate by the sales channel

grouped = df_custumers_data.groupby('sales_channel')['response'].value_counts(normalize=True).unstack().fillna(0)
grouped
# Out:
# response             No       Yes       nan
# sales_channel
# Agent          0.763892  0.180053  0.056054
# Branch         0.840172  0.107876  0.051952
# Call Center    0.836992  0.103223  0.059785
# Web            0.820418  0.108856  0.070726

# %%
grouped['response_rate'] = grouped['Yes'] * 100
grouped
# Out:
# response             No       Yes       nan  response_rate
# sales_channel
# Agent          0.763892  0.180053  0.056054      18.005339
# Branch         0.840172  0.107876  0.051952      10.787558
# Call Center    0.836992  0.103223  0.059785      10.322279
# Web            0.820418  0.108856  0.070726      10.885609

# %%
# Reset the index to make 'Sales Channel' a regular column
grouped.reset_index(inplace=True)
grouped

# Create a bar plot to visualize the response rate by sales channel using seaborn
sns.barplot(x='sales_channel', y='response_rate', data=grouped, palette="Blues")

# Set labels and title
plt.xlabel("Sales Channel")
plt.ylabel("Response Rate (%)")
plt.title("Response Rate by Sales Channel")

# Show the plot
plt.show()

# %%
# Show a plot of the response rate by the total claim amount

# Updating the DF with the total claim amount

# grouped['total_claim_amount']=df_custumers_data['total_claim_amount'] 

# sns.scatterplot(x='total_claim_amount', y='response_rate', data=grouped)

# Set labels and title
# plt.xlabel("Claim Amount")
# plt.ylabel("Response Rate (%)")
# plt.title("Response Rate by Claim Amount")

# Show the plot
# plt.show()

# %%
# Response rate by claim amount 

grouped_2 = df_custumers_data.groupby('total_claim_amount')['response'].value_counts(normalize=True).unstack().fillna(0)
grouped_2
# Out:
# response             No  Yes  nan
# total_claim_amount
# 0.099007            1.0  0.0  0.0
# 0.382107            1.0  0.0  0.0
# 0.423310            1.0  0.0  0.0
# 0.517753            1.0  0.0  0.0
# 0.769185            0.5  0.0  0.5
# ...                 ...  ...  ...
# 2345.413441         1.0  0.0  0.0
# 2452.894264         1.0  0.0  0.0
# 2552.343856         1.0  0.0  0.0
# 2759.794354         1.0  0.0  0.0
# 2893.239678         1.0  0.0  0.0
#
# [5106 rows x 3 columns]

# %%
grouped_2['response_rate'] = grouped_2['Yes'] * 100
grouped_2.reset_index(inplace=True)
grouped_2.tail(50)
# Out:
# response  total_claim_amount        No  Yes       nan  response_rate
# 5056             1612.962321  1.000000  0.0  0.000000            0.0
# 5057             1620.000000  1.000000  0.0  0.000000            0.0
# 5058             1621.560425  1.000000  0.0  0.000000            0.0
# 5059             1644.690622  1.000000  0.0  0.000000            0.0
# 5060             1654.202174  1.000000  0.0  0.000000            0.0
# 5061             1684.800000  1.000000  0.0  0.000000            0.0
# 5062             1706.400000  1.000000  0.0  0.000000            0.0
# 5063             1724.234933  1.000000  0.0  0.000000            0.0
# 5064             1737.320276  1.000000  0.0  0.000000            0.0
# 5065             1742.400000  1.000000  0.0  0.000000            0.0
# 5066             1756.800000  1.000000  0.0  0.000000            0.0
# 5067             1767.348807  1.000000  0.0  0.000000            0.0
# 5068             1777.471271  1.000000  0.0  0.000000            0.0
# 5069             1778.400000  1.000000  0.0  0.000000            0.0
# 5070             1814.400000  0.500000  0.0  0.500000            0.0
# 5071             1823.730828  0.666667  0.0  0.333333            0.0
# 5072             1828.800000  1.000000  0.0  0.000000            0.0
# 5073             1833.182529  1.000000  0.0  0.000000            0.0
# 5074             1836.000000  1.000000  0.0  0.000000            0.0
# 5075             1853.202354  1.000000  0.0  0.000000            0.0
# 5076             1921.248929  1.000000  0.0  0.000000            0.0
# 5077             1943.772393  0.500000  0.0  0.500000            0.0
# 5078             1950.725547  1.000000  0.0  0.000000            0.0
# 5079             1953.879720  1.000000  0.0  0.000000            0.0
# 5080             1956.368115  1.000000  0.0  0.000000            0.0
# 5081             1961.162049  1.000000  0.0  0.000000            0.0
# 5082             1965.600000  1.000000  0.0  0.000000            0.0
# 5083             1972.800000  1.000000  0.0  0.000000            0.0
# 5084             1979.444237  1.000000  0.0  0.000000            0.0
# 5085             1980.000000  1.000000  0.0  0.000000            0.0
# 5086             1985.999807  1.000000  0.0  0.000000            0.0
# 5087             2027.724442  1.000000  0.0  0.000000            0.0
# 5088             2042.569089  0.500000  0.0  0.500000            0.0
# 5089             2052.000000  1.000000  0.0  0.000000            0.0
# 5090             2059.200000  1.000000  0.0  0.000000            0.0
# 5091             2069.309854  1.000000  0.0  0.000000            0.0
# 5092             2092.523421  0.500000  0.0  0.500000            0.0
# 5093             2145.600000  1.000000  0.0  0.000000            0.0
# 5094             2156.011022  1.000000  0.0  0.000000            0.0
# 5095             2201.327879  1.000000  0.0  0.000000            0.0
# 5096             2270.508697  1.000000  0.0  0.000000            0.0
# 5097             2275.265075  1.000000  0.0  0.000000            0.0
# 5098             2294.631639  1.000000  0.0  0.000000            0.0
# 5099             2306.508397  1.000000  0.0  0.000000            0.0
# 5100             2327.166394  1.000000  0.0  0.000000            0.0
# 5101             2345.413441  1.000000  0.0  0.000000            0.0
# 5102             2452.894264  1.000000  0.0  0.000000            0.0
# 5103             2552.343856  1.000000  0.0  0.000000            0.0
# 5104             2759.794354  1.000000  0.0  0.000000            0.0
# 5105             2893.239678  1.000000  0.0  0.000000            0.0

# %%
grouped_2["response_rate"].unique()
# Out:
# array([  0.        , 100.        ,  87.5       ,  75.        ,
#         85.71428571,  88.88888889,  90.90909091,  16.17647059,
#         18.51851852,   7.36842105,  70.        ,  20.45454545,
#         33.09352518,  15.51724138,  13.13131313,  21.8487395 ,
#         22.22222222,  12.17391304,  31.78294574,   6.06060606,
#         43.75      ,  20.68965517,  17.64705882,  27.5862069 ,
#         35.13513514,  30.        ,  77.77777778,  31.25      ,
#         22.58064516,  66.66666667,  15.38461538,  20.        ,
#         20.96774194,  23.07692308,  16.66666667,  13.7254902 ,
#         33.33333333,  25.        ,  26.76056338,  32.55813953,
#         11.53846154,  18.30985915,  43.47826087,  21.875     ,
#         37.73584906,  16.27906977,  21.95121951,  27.45098039,
#         13.46153846,  29.16666667,  48.97959184,  14.58333333,
#         36.36363636,  48.14814815,  31.57894737,  23.68421053,
#         46.66666667,  46.15384615,  56.25      ,  50.        ,
#         54.54545455])

# %%
grouped_2.head(50)
# Out:
# response  total_claim_amount        No  Yes       nan  response_rate
# 0                   0.099007  1.000000  0.0  0.000000            0.0
# 1                   0.382107  1.000000  0.0  0.000000            0.0
# 2                   0.423310  1.000000  0.0  0.000000            0.0
# 3                   0.517753  1.000000  0.0  0.000000            0.0
# 4                   0.769185  0.500000  0.0  0.500000            0.0
# 5                   0.887629  1.000000  0.0  0.000000            0.0
# 6                   1.208908  1.000000  0.0  0.000000            0.0
# 7                   1.332349  0.500000  0.0  0.500000            0.0
# 8                   1.489470  1.000000  0.0  0.000000            0.0
# 9                   1.587888  1.000000  0.0  0.000000            0.0
# 10                  1.687291  1.000000  0.0  0.000000            0.0
# 11                  1.838367  1.000000  0.0  0.000000            0.0
# 12                  1.924709  1.000000  0.0  0.000000            0.0
# 13                  2.016239  1.000000  0.0  0.000000            0.0
# 14                  2.028223  1.000000  0.0  0.000000            0.0
# 15                  2.173552  1.000000  0.0  0.000000            0.0
# 16                  2.455033  1.000000  0.0  0.000000            0.0
# 17                  2.540090  1.000000  0.0  0.000000            0.0
# 18                  2.549986  1.000000  0.0  0.000000            0.0
# 19                  2.574682  1.000000  0.0  0.000000            0.0
# 20                  2.704934  1.000000  0.0  0.000000            0.0
# 21                  2.823303  1.000000  0.0  0.000000            0.0
# 22                  2.964380  0.500000  0.0  0.500000            0.0
# 23                  3.200851  1.000000  0.0  0.000000            0.0
# 24                  3.246203  1.000000  0.0  0.000000            0.0
# 25                  3.406136  0.333333  0.0  0.666667            0.0
# 26                  3.463700  1.000000  0.0  0.000000            0.0
# 27                  3.468912  1.000000  0.0  0.000000            0.0
# 28                  3.550000  1.000000  0.0  0.000000            0.0
# 29                  3.772105  1.000000  0.0  0.000000            0.0
# 30                  4.074222  0.500000  0.0  0.500000            0.0
# 31                  4.110585  1.000000  0.0  0.000000            0.0
# 32                  4.216231  1.000000  0.0  0.000000            0.0
# 33                  4.237520  1.000000  0.0  0.000000            0.0
# 34                  4.238626  1.000000  0.0  0.000000            0.0
# 35                  4.334425  1.000000  0.0  0.000000            0.0
# 36                  4.612620  1.000000  0.0  0.000000            0.0
# 37                  4.619402  1.000000  0.0  0.000000            0.0
# 38                  4.719043  1.000000  0.0  0.000000            0.0
# 39                  4.845348  1.000000  0.0  0.000000            0.0
# 40                  5.395300  1.000000  0.0  0.000000            0.0
# 41                  5.434505  1.000000  0.0  0.000000            0.0
# 42                  5.453269  1.000000  0.0  0.000000            0.0
# 43                  5.573179  1.000000  0.0  0.000000            0.0
# 44                  5.622751  1.000000  0.0  0.000000            0.0
# 45                  5.661684  1.000000  0.0  0.000000            0.0
# 46                  5.674809  1.000000  0.0  0.000000            0.0
# 47                  5.746657  0.666667  0.0  0.333333            0.0
# 48                  5.894778  0.500000  0.0  0.500000            0.0
# 49                  6.077440  1.000000  0.0  0.000000            0.0

# %%
plt.scatter(x = grouped_2['total_claim_amount'], y = grouped_2['response_rate'])
plt.xlabel("Claim Amount")
plt.ylabel("Response Rate (%)")
plt.title("Response Rate by Claim Amount")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Show a plot of the response rate by income

grouped_3 = df_custumers_data.groupby('income')['response'].value_counts(normalize=True).unstack().fillna(0)
grouped_3['response_rate'] = grouped_3['Yes'] * 100
grouped_3.reset_index(inplace=True)
grouped_3.head(50)
# Out:
# response  income        No       Yes       nan  response_rate
# 0              0  0.858271  0.081091  0.060639       8.109078
# 1          10037  1.000000  0.000000  0.000000       0.000000
# 2          10074  1.000000  0.000000  0.000000       0.000000
# 3          10097  1.000000  0.000000  0.000000       0.000000
# 4          10105  1.000000  0.000000  0.000000       0.000000
# 5          10147  1.000000  0.000000  0.000000       0.000000
# 6          10180  1.000000  0.000000  0.000000       0.000000
# 7          10194  1.000000  0.000000  0.000000       0.000000
# 8          10211  1.000000  0.000000  0.000000       0.000000
# 9          10237  1.000000  0.000000  0.000000       0.000000
# 10         10269  0.500000  0.000000  0.500000       0.000000
# 11         10275  1.000000  0.000000  0.000000       0.000000
# 12         10312  0.000000  1.000000  0.000000     100.000000
# 13         10334  1.000000  0.000000  0.000000       0.000000
# 14         10337  1.000000  0.000000  0.000000       0.000000
# 15         10375  1.000000  0.000000  0.000000       0.000000
# 16         10384  1.000000  0.000000  0.000000       0.000000
# 17         10458  1.000000  0.000000  0.000000       0.000000
# 18         10475  1.000000  0.000000  0.000000       0.000000
# 19         10511  1.000000  0.000000  0.000000       0.000000
# 20         10517  1.000000  0.000000  0.000000       0.000000
# 21         10540  1.000000  0.000000  0.000000       0.000000
# 22         10563  1.000000  0.000000  0.000000       0.000000
# 23         10621  0.000000  1.000000  0.000000     100.000000
# 24         10629  1.000000  0.000000  0.000000       0.000000
# 25         10710  1.000000  0.000000  0.000000       0.000000
# 26         10738  1.000000  0.000000  0.000000       0.000000
# 27         10743  0.500000  0.000000  0.500000       0.000000
# 28         10787  1.000000  0.000000  0.000000       0.000000
# 29         10853  1.000000  0.000000  0.000000       0.000000
# 30         10860  1.000000  0.000000  0.000000       0.000000
# 31         10892  1.000000  0.000000  0.000000       0.000000
# 32         11033  1.000000  0.000000  0.000000       0.000000
# 33         11097  1.000000  0.000000  0.000000       0.000000
# 34         11167  1.000000  0.000000  0.000000       0.000000
# 35         11193  1.000000  0.000000  0.000000       0.000000
# 36         11276  1.000000  0.000000  0.000000       0.000000
# 37         11343  1.000000  0.000000  0.000000       0.000000
# 38         11417  1.000000  0.000000  0.000000       0.000000
# 39         11432  0.000000  1.000000  0.000000     100.000000
# 40         11489  1.000000  0.000000  0.000000       0.000000
# 41         11538  1.000000  0.000000  0.000000       0.000000
# 42         11607  1.000000  0.000000  0.000000       0.000000
# 43         11612  1.000000  0.000000  0.000000       0.000000
# 44         11621  0.500000  0.000000  0.500000       0.000000
# 45         11652  1.000000  0.000000  0.000000       0.000000
# 46         11656  1.000000  0.000000  0.000000       0.000000
# 47         11689  1.000000  0.000000  0.000000       0.000000
# 48         11698  1.000000  0.000000  0.000000       0.000000
# 49         11721  0.500000  0.000000  0.500000       0.000000

# %%
plt.scatter(x = grouped_3['income'], y = grouped_3['response_rate'])
plt.xlabel("Income")
plt.ylabel("Response Rate (%)")
plt.title("Response Rate by Income")

plt.show()

# %%
sns.boxplot(x = grouped_3['income'], data = grouped_3)
plt.show()
