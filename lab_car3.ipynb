# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns


data1 = pd.read_csv("csv_files/marketing_customer_analysis.csv")
dataframe = data1

display(dataframe)
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %% [markdown]
# ### Question 1: Show DataFrame info

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %% [markdown]
# ### Question 2: Describe DataFrame

# %%
summary = dataframe.describe(include = "all")
display(summary)
# Out:
#        Customer       State  Customer Lifetime Value Response Coverage  \
# count      9134        9134              9134.000000     9134     9134
# unique     9134           5                      NaN        2        3
# top     BU79786  California                      NaN       No    Basic
# freq          1        3150                      NaN     7826     5568
# mean        NaN         NaN              8004.940475      NaN      NaN
# std         NaN         NaN              6870.967608      NaN      NaN
# min         NaN         NaN              1898.007675      NaN      NaN
# 25%         NaN         NaN              3994.251794      NaN      NaN
# 50%         NaN         NaN              5780.182197      NaN      NaN
# 75%         NaN         NaN              8962.167041      NaN      NaN
# max         NaN         NaN             83325.381190      NaN      NaN
#
#        Education Effective To Date EmploymentStatus Gender        Income  ...  \
# ...

# %% [markdown]
# ### Question 3: Show a plot of the total number of responses.

# %%
total = dataframe["Response"].value_counts().sum()

sns.countplot(x="Response", data=dataframe).set(title = "Total number of responses")
# Out:
# [Text(0.5, 1.0, 'Total number of responses')]

# %% [markdown]
# ### Question 4: Show a plot of the response rate by the sales channel

# %%
dataframe.groupby("Response")["Sales Channel"].value_counts(normalize=True).unstack("Response").plot.bar (stacked=False)
# Out:
# <AxesSubplot:xlabel='Sales Channel'>

# %% [markdown]
# ### Question 5: Show a plot of the response rate by the total claim amount.

# %%
#rr = dataframe["Response"].value_counts(normalize=True)

sns.catplot(x="Response", y="Total Claim Amount", data=dataframe, kind="bar")

# %% [markdown]
# ### Question 6: Show a plot of the response rate by income

# %%
sns.catplot(x="Response", y="Income", data=dataframe, kind="bar")
